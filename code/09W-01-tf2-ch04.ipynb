# %%
import math
import numpy as np
import matplotlib.pyplot as plt

def sigmoid(x):
    return 1 / (1 + math.exp(-x))

x = np.arange(-6, 6, 0.01)
sigmoid_x = [sigmoid(z) for z in x]
tanh_x = [math.tanh(z) for z in x]

plt.figure(figsize=(8, 6)) 

plt.axhline(0, color='gray')
plt.axvline(0, color='gray')
plt.plot(x, sigmoid_x, 'b-', label='sigmoid')
plt.plot(x, tanh_x, 'r--', label='tanh')
plt.legend()
plt.show()

# %%
import tensorflow as tf
import numpy as np

X = [0.3, -0.78, 1.26, 0.03, 1.11, 0.24, -0.24, -0.47, -0.77, -0.37, -0.85, -0.41, -0.27, 0.02, -0.76, 2.66]
Y = [12.27, 14.44, 11.87, 18.75, 17.52, 16.37, 19.78, 19.51, 12.65, 14.74, 10.72, 21.94, 12.83, 15.51, 17.14, 14.42]

model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=6, activation='tanh', input_shape=(1,)),
    tf.keras.layers.Dense(units=1)
])

model.compile(optimizer=tf.keras.optimizers.SGD(lr=0.1), loss='mse')

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 6)                 12
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 19
# Trainable params: 19
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X, Y, epochs=10)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 0s 1ms/step - loss: 255.0509
# Epoch 2/10
# 1/1 [==============================] - 0s 1ms/step - loss: 106.6729
# Epoch 3/10
# 1/1 [==============================] - 0s 1ms/step - loss: 9.5996
# Epoch 4/10
# 1/1 [==============================] - 0s 1ms/step - loss: 9.5741
# Epoch 5/10
# 1/1 [==============================] - 0s 1ms/step - loss: 9.5634
# Epoch 6/10
# 1/1 [==============================] - 0s 1ms/step - loss: 9.5530
# Epoch 7/10
# 1/1 [==============================] - 0s 2ms/step - loss: 9.5425
# Epoch 8/10
# 1/1 [==============================] - 0s 1ms/step - loss: 9.5319
# Epoch 9/10
# 1/1 [==============================] - 0s 2ms/step - loss: 9.5210
# Epoch 10/10
# 1/1 [==============================] - 0s 1ms/step - loss: 9.5099

# %%
model.predict(X)
# Out:
# array([[15.7619505],
#        [15.856036 ],
#        [14.997754 ],
#        [15.863993 ],
#        [15.132754 ],
#        [15.790294 ],
#        [15.904589 ],
#        [15.900094 ],
#        [15.857916 ],
#        [15.905764 ],
#        [15.842288 ],
#        [15.904123 ],
#        [15.905804 ],
#        [15.866535 ],
#        [15.859774 ],
#        [14.232656 ]], dtype=float32)

# %%
import matplotlib.pyplot as plt

line_x = np.arange(min(X), max(X), 0.01)
line_y = model.predict(line_x)

plt.plot(line_x, line_y, 'r-')
plt.plot(X, Y, 'bo')

plt.xlabel('Population Growth Rate (%)')
plt.ylabel('Elderly Population Rate (%)')
plt.show()

# %%
import tensorflow as tf
import numpy as np

X = [0.3, -0.78, 1.26, 0.03, 1.11, 0.24, -0.24, -0.47, -0.77, -0.37, -0.85, -0.41, -0.27, 0.02, -0.76, 2.66]
Y = [12.27, 14.44, 11.87, 18.75, 17.52, 16.37, 19.78, 19.51, 12.65, 14.74, 10.72, 21.94, 12.83, 15.51, 17.14, 14.42]

model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=6, activation='tanh', input_shape=(1,)),
    tf.keras.layers.Dense(units=1)
])

model.compile(optimizer=tf.keras.optimizers.SGD(lr=0.1), loss='mse')
model.summary()
model.fit(X, Y, epochs=10)
model.predict(X)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 6)                 12
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 19
# Trainable params: 19
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1/1 [==============================] - 0s 1ms/step - loss: 253.5142
# Epoch 2/10
# 1/1 [==============================] - 0s 1ms/step - loss: 105.1783
# Epoch 3/10
# 1/1 [==============================] - 0s 997us/step - loss: 9.7513
# Epoch 4/10
# 1/1 [==============================] - 0s 1ms/step - loss: 9.6660
# Epoch 5/10
# 1/1 [==============================] - 0s 1ms/step - loss: 9.6515
# Epoch 6/10
# 1/1 [==============================] - 0s 986us/step - loss: 9.6453
# Epoch 7/10
# 1/1 [==============================] - 0s 2ms/step - loss: 9.6406
# Epoch 8/10
# 1/1 [==============================] - 0s 1ms/step - loss: 9.6359
# Epoch 9/10
# 1/1 [==============================] - 0s 2ms/step - loss: 9.6310
# Epoch 10/10
# 1/1 [==============================] - 0s 2ms/step - loss: 9.6259
# array([[15.8603325],
#        [15.708679 ],
#        [15.545311 ],
#        [15.859642 ],
#        [15.634916 ],
#        [15.862854 ],
#        [15.831162 ],
#        [15.788504 ],
#        [15.711608 ],
#        [15.808948 ],
#        [15.687567 ],
#        [15.801106 ],
#        [15.826492 ],
#        [15.859052 ],
#        [15.714516 ],
#        [13.874145 ]], dtype=float32)

# %%
import tensorflow as tf
import numpy as np

X = [0.3, -0.78, 1.26, 0.03, 1.11, 0.24, -0.24, -0.47, -0.77, -0.37, -0.85, -0.41, -0.27, 0.02, -0.76, 2.66]
Y = [12.27, 14.44, 11.87, 18.75, 17.52, 16.37, 19.78, 19.51, 12.65, 14.74, 10.72, 21.94, 12.83, 15.51, 17.14, 14.42]

a = tf.Variable(tf.random.uniform([1], 0, 1))
b = tf.Variable(tf.random.uniform([1], 0, 1))

def compute_loss():
    y_pred = a * X + b
    loss = tf.reduce_mean((Y - y_pred) ** 2)
    return loss

optimizer = tf.keras.optimizers.Adam(lr=0.07)
for i in range(1000):
    optimizer.minimize(compute_loss, var_list=[a, b])
    
    if i % 100 == 99:
        print(i, 'a:', a.numpy(), 'b:', b.numpy(), 'loss:', compute_loss().numpy())
# Out:
# 99 a: [0.125654] b: [6.6170893] loss: 91.53356
# 199 a: [-0.11332531] b: [11.122853] loss: 30.403198
# 299 a: [-0.25406355] b: [13.761159] loss: 13.413427
# 399 a: [-0.32064235] b: [15.009475] loss: 10.215187
# 499 a: [-0.34585744] b: [15.482254] loss: 9.815715
# 599 a: [-0.35352486] b: [15.62602] loss: 9.782675
# 699 a: [-0.355401] b: [15.661196] loss: 9.780869
# 799 a: [-0.3557691] b: [15.668097] loss: 9.780806
# 899 a: [-0.35582638] b: [15.669175] loss: 9.780804
# 999 a: [-0.35583323] b: [15.669302] loss: 9.780804

# %%
import matplotlib.pyplot as plt

line_x = np.arange(min(X), max(X), 0.01)
line_y = a * line_x + b

plt.plot(line_x, line_y, 'r-')
plt.plot(X, Y, 'bo')
plt.xlabel('Population Growth Rate (%)')
plt.ylabel('Elderly Population Rate (%)')
plt.show()

# %%
import math
def sigmoid(x):
    return 1 / (1 + math.exp(-x))

x = np.arange(-5, 5, 0.01)
sigmoid_x = [sigmoid(z) for z in x]
tanh_x = [math.tanh(z) for z in x]
relu = [0 if z < 0 else z for z in x]

plt.figure(figsize=(8, 6)) 

plt.axhline(0, color='gray')
plt.axvline(0, color='gray')
plt.plot(x, sigmoid_x, 'b-', label='sigmoid')
plt.plot(x, tanh_x, 'r--', label='tanh')
plt.plot(x, relu, 'g.', label='relu')
plt.legend()
plt.show()

# %%
from tensorflow.keras.datasets import boston_housing
(train_X, train_Y), (test_X, test_Y) = boston_housing.load_data()

print(train_X.shape, test_X.shape)
print(train_X[0])
print(train_Y[0])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57344/57026 [==============================] - 0s 0us/step
# (404, 13) (102, 13)
# [  1.23247   0.        8.14      0.        0.538     6.142    91.7
#    3.9769    4.      307.       21.      396.9      18.72   ]
# 15.2

# %%
x_mean = train_X.mean(axis=0)
x_std = train_X.std(axis=0)
train_X -= x_mean
train_X /= x_std
test_X -= x_mean
test_X /= x_std

y_mean = train_Y.mean(axis=0)
y_std = train_Y.std(axis=0)
train_Y -= y_mean
train_Y /= y_std
test_Y -= y_mean
test_Y /= y_std

print(train_X[0])
print(train_Y[0])
# Out:
# [-0.27224633 -0.48361547 -0.43576161 -0.25683275 -0.1652266  -0.1764426
#   0.81306188  0.1166983  -0.62624905 -0.59517003  1.14850044  0.44807713
#   0.8252202 ]
# -0.7821526033779157

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(units=52, activation='relu', input_shape=(13,)),
    tf.keras.layers.Dense(units=39, activation='relu'),
    tf.keras.layers.Dense(units=26, activation='relu'),
    tf.keras.layers.Dense(units=1)
])

model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.07), loss='mse')

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 52)                728
# _________________________________________________________________
# dense_5 (Dense)              (None, 39)                2067
# _________________________________________________________________
# dense_6 (Dense)              (None, 26)                1040
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 27
# =================================================================
# Total params: 3,862
# Trainable params: 3,862
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_X, train_Y, epochs=25, batch_size=32, validation_split=0.25)
# Out:
# Epoch 1/25
# 10/10 [==============================] - 0s 14ms/step - loss: 2.5420 - val_loss: 1.0050
# Epoch 2/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4933 - val_loss: 0.7173
# Epoch 3/25
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3465 - val_loss: 0.2772
# Epoch 4/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2158 - val_loss: 0.2871
# Epoch 5/25
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1792 - val_loss: 0.2643
# Epoch 6/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1726 - val_loss: 0.4818
# Epoch 7/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2657 - val_loss: 0.2215
# Epoch 8/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1733 - val_loss: 0.2270
# Epoch 9/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1439 - val_loss: 0.1840
# Epoch 10/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1161 - val_loss: 0.1925
# Epoch 11/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1091 - val_loss: 0.1745
# Epoch 12/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1095 - val_loss: 0.1484
# Epoch 13/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1208 - val_loss: 0.1977
# Epoch 14/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1100 - val_loss: 0.1394
# Epoch 15/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1127 - val_loss: 0.1541
# Epoch 16/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0838 - val_loss: 0.1442
# Epoch 17/25
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0829 - val_loss: 0.1321
# Epoch 18/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0786 - val_loss: 0.1334
# Epoch 19/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0717 - val_loss: 0.1396
# Epoch 20/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0721 - val_loss: 0.1262
# Epoch 21/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0653 - val_loss: 0.1975
# Epoch 22/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1029 - val_loss: 0.1962
# Epoch 23/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1312 - val_loss: 0.1658
# Epoch 24/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1111 - val_loss: 0.1930
# Epoch 25/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1385 - val_loss: 0.4142

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], 'b-', label='loss')
plt.plot(history.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
model.evaluate(test_X, test_Y)
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4242
# 0.424249529838562

# %%
import matplotlib.pyplot as plt

pred_Y = model.predict(test_X)

plt.figure(figsize=(8,8))
plt.plot(test_Y, pred_Y, 'b.')
plt.axis([min(test_Y), max(test_Y), min(test_Y), max(test_Y)])

plt.plot([min(test_Y), max(test_Y)], [min(test_Y), max(test_Y)], ls="--", c=".5")
plt.xlabel('test_Y')
plt.ylabel('pred_Y')

plt.show()

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=52, activation='relu', input_shape=(13,)),
    tf.keras.layers.Dense(units=39, activation='relu'),
    tf.keras.layers.Dense(units=26, activation='relu'),
    tf.keras.layers.Dense(units=1)
])

model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.07), loss='mse')

history = model.fit(train_X, train_Y, epochs=25, batch_size=32, validation_split=0.25,
                    callbacks=[tf.keras.callbacks.EarlyStopping(patience=3, monitor='val_loss')])
# Out:
# Epoch 1/25
# 10/10 [==============================] - 0s 12ms/step - loss: 1.6168 - val_loss: 0.9942
# Epoch 2/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5583 - val_loss: 0.6099
# Epoch 3/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3442 - val_loss: 0.3126
# Epoch 4/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2756 - val_loss: 0.3850
# Epoch 5/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2920 - val_loss: 0.2495
# Epoch 6/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2556 - val_loss: 0.3699
# Epoch 7/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2208 - val_loss: 0.2355
# Epoch 8/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1844 - val_loss: 0.2753
# Epoch 9/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1614 - val_loss: 0.1762
# Epoch 10/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1718 - val_loss: 0.2167
# Epoch 11/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1555 - val_loss: 0.1993
# Epoch 12/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1436 - val_loss: 0.1713
# Epoch 13/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1779 - val_loss: 0.3263
# Epoch 14/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1505 - val_loss: 0.2001
# Epoch 15/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2044 - val_loss: 0.4673

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], 'b-', label='loss')
plt.plot(history.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
model.evaluate(test_X, test_Y)
# Out:
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4993
# 0.4992962181568146

# %%
import matplotlib.pyplot as plt

pred_Y = model.predict(test_X)

plt.figure(figsize=(8,8))
plt.plot(test_Y, pred_Y, 'b.')
plt.axis([min(test_Y), max(test_Y), min(test_Y), max(test_Y)])

plt.plot([min(test_Y), max(test_Y)], [min(test_Y), max(test_Y)], ls="--", c=".3")
plt.xlabel('test_Y')
plt.ylabel('pred_Y')

plt.show()

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=52, activation='relu', input_shape=(13,)),
    tf.keras.layers.Dropout(.1),
    tf.keras.layers.Dense(units=39, activation='relu'),
    tf.keras.layers.Dense(units=26, activation='relu'),
    tf.keras.layers.Dropout(.1),
    tf.keras.layers.Dense(units=1)
])

model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.07), loss='mse')

history = model.fit(train_X, train_Y, epochs=25, batch_size=32, validation_split=0.25,
                    callbacks=[tf.keras.callbacks.EarlyStopping(patience=4, monitor='val_loss')])
# Out:
# Epoch 1/25
# 10/10 [==============================] - 0s 13ms/step - loss: 1.3429 - val_loss: 0.5521
# Epoch 2/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3686 - val_loss: 0.2359
# Epoch 3/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2865 - val_loss: 0.3430
# Epoch 4/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3022 - val_loss: 0.2535
# Epoch 5/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2357 - val_loss: 0.2104
# Epoch 6/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3221 - val_loss: 1.0727
# Epoch 7/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4514 - val_loss: 0.3973
# Epoch 8/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4418 - val_loss: 0.5990
# Epoch 9/25
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5531 - val_loss: 0.5514

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], 'b-', label='loss')
plt.plot(history.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
model.evaluate(test_X, test_Y)
# Out:
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6078
# 0.6077752113342285

# %%
import matplotlib.pyplot as plt

pred_Y = model.predict(test_X)

plt.figure(figsize=(8,8))
plt.plot(test_Y, pred_Y, 'b.')
plt.axis([min(test_Y), max(test_Y), min(test_Y), max(test_Y)])

plt.plot([min(test_Y), max(test_Y)], [min(test_Y), max(test_Y)], ls="--", c=".3")
plt.xlabel('test_Y')
plt.ylabel('pred_Y')

plt.show()
# Out:
# WARNING:tensorflow:5 out of the last 22 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7b2a7f9bf8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
