# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.3.0

# %%
import tensorflow as tf
from tensorflow import keras

fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
train_images, test_images = train_images / 255.0, test_images / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
model = keras.Sequential([
                          keras.layers.Flatten(input_shape=(28, 28)),
                          keras.layers.Dense(512, activation='relu'),
                          keras.layers.Dense(256, activation='relu'),
                          keras.layers.Dense(128, activation='relu'),
                          keras.layers.Dense(10, activation='softmax')])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               401920
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 567,434
# Trainable params: 567,434
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(train_images, train_labels, epochs=8)

test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
print('\n테스트 정확도:', test_acc)
# Out:
# Epoch 1/8
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.4784 - accuracy: 0.8262
# Epoch 2/8
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.3655 - accuracy: 0.8662
# Epoch 3/8
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.3292 - accuracy: 0.8780
# Epoch 4/8
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.3046 - accuracy: 0.8869
# Epoch 5/8
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2864 - accuracy: 0.8924
# Epoch 6/8
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2702 - accuracy: 0.8980
# Epoch 7/8
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.2577 - accuracy: 0.9023
# Epoch 8/8
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2472 - accuracy: 0.9059
# 313/313 - 1s - loss: 0.3349 - accuracy: 0.8809
#
# 테스트 정확도: 0.8809000253677368

# %%
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %%
train_images.shape, test_images.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28))

# %%
train_labels.shape, test_labels.shape
# Out:
# ((60000,), (10000,))

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
class_names
# Out:
# ['T-shirt/top',
#  'Trouser',
#  'Pullover',
#  'Dress',
#  'Coat',
#  'Sandal',
#  'Shirt',
#  'Sneaker',
#  'Bag',
#  'Ankle boot']

# %%
print(train_labels[0])
print(class_names[train_labels[0]])
# Out:
# 9
# Ankle boot

# %%
plt.figure()
plt.imshow(train_images[0])
plt.title('index: 0, ' + class_names[train_labels[0]])
plt.colorbar()
plt.show()

# %%
plt.figure(figsize = (10, 6))

plt.subplot(2, 2, 1)
plt.subplot(2, 2, 2)
plt.subplot(2, 2, 3) 
plt.subplot(2, 2, 4) 
plt.show()

# %%
plt.figure(figsize = (10, 6))

plt.subplot(2, 2, 1)
plt.subplot(2, 2, 2)
plt.subplot(2, 1, 2) 

plt.show()

# %%
plt.figure(figsize = (10, 6))

plt.subplot(411)
plt.subplot(423)
plt.subplot(424)
plt.subplot(425)
plt.subplot(426)
plt.subplot(413)
plt.subplot(414)

plt.show()

# %%
import numpy as np

x = np.arange(0, 5, 0.01)

plt.figure(figsize=(10, 12))

plt.subplot(411)
plt.plot(x, np.sqrt(x))
plt.grid()

plt.subplot(423)
plt.plot(x, x**2)
plt.grid()

plt.subplot(424)
plt.plot(x, x**3)
plt.grid()

plt.subplot(413)
plt.plot(x, np.sin(x))
plt.grid()

plt.subplot(414)
plt.plot(x, np.cos(x))
plt.grid()

plt.show()

# %%
import numpy as np

x = np.arange(0, 5, 0.01)

plt.figure(figsize=(10, 12))

plt.subplot(411)
plt.plot(x, np.sqrt(x))
plt.grid()

plt.subplot(423)
plt.plot(x, x**2)
plt.grid()

plt.subplot(424)
plt.plot(x, x**3)
plt.grid()

plt.subplot(413)
plt.plot(x, np.sin(x))
plt.grid()

plt.subplot(414)
plt.plot(x, np.cos(x))
plt.grid()

plt.subplot(427)
plt.plot(x, np.exp(x))
plt.grid()

plt.subplot(4, 2, 8)
plt.plot(x, np.exp(-x))
plt.grid()

plt.show()

# %%
import numpy as np

x = np.arange(0, 5, 0.01)

plt.figure(figsize=(10, 12))

plt.subplot(511)
plt.plot(x, np.sqrt(x))
plt.grid()

plt.subplot(523)
plt.plot(x, x**2)
plt.grid()

plt.subplot(524)
plt.plot(x, x**3)
plt.grid()

plt.subplot(513)
plt.plot(x, np.sin(x))
plt.grid()

plt.subplot(514)
plt.plot(x, np.cos(x))
plt.grid()


plt.subplot(529)
plt.plot(x, np.exp(x))
plt.grid()


plt.subplot(5, 2, 10)
plt.plot(x, np.exp(-x))
plt.grid()

plt.show()

# %%
plt.figure(figsize = (12, 10))
for i in range(30):
    plt.subplot(5, 6, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(train_images[i], cmap = plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %%
from random import sample

rows, cols = 5, 6 
idx = sorted(sample(range(len(train_images)), rows * cols))
print(idx)

cnt = 0
plt.figure(figsize=(12, 10))

for i in idx:
    cnt += 1
    plt.subplot(rows, cols, cnt)
    tmp = str(i) + ' ' + str(class_names[train_labels[i]])
    plt.title(tmp)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(train_images[i], cmap='Greys')

plt.tight_layout()
plt.show()
# Out:
# [1317, 5049, 6184, 10456, 13352, 15152, 17040, 18046, 18392, 19132, 20118, 21397, 22974, 26241, 27235, 29457, 31289, 31428, 35500, 35511, 35942, 38865, 40796, 41736, 43750, 44385, 51527, 53825, 55650, 58190]

# %%
train_images, test_images = train_images / 255.0, test_images / 255.0

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(512, activation='relu'),
    keras.layers.Dense(1024, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dropout(.2),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_images, train_labels, epochs = 10, validation_split=0.2)

test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose = 3)
print('\n테스트 정확도:', test_acc)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 25s 16ms/step - loss: 0.5231 - accuracy: 0.8119 - val_loss: 0.5307 - val_accuracy: 0.8242
# Epoch 2/10
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.3902 - accuracy: 0.8586 - val_loss: 0.3653 - val_accuracy: 0.8684
# Epoch 3/10
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.3512 - accuracy: 0.8741 - val_loss: 0.3783 - val_accuracy: 0.8671
# Epoch 4/10
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.3299 - accuracy: 0.8804 - val_loss: 0.3650 - val_accuracy: 0.8652
# Epoch 5/10
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.3111 - accuracy: 0.8868 - val_loss: 0.3355 - val_accuracy: 0.8791
# Epoch 6/10
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.2942 - accuracy: 0.8927 - val_loss: 0.3436 - val_accuracy: 0.8774
# Epoch 7/10
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.2794 - accuracy: 0.8974 - val_loss: 0.3338 - val_accuracy: 0.8883
# Epoch 8/10
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.2711 - accuracy: 0.8981 - val_loss: 0.3207 - val_accuracy: 0.8852
# Epoch 9/10
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.2587 - accuracy: 0.9047 - val_loss: 0.3594 - val_accuracy: 0.8776
# Epoch 10/10
# 1500/1500 [==============================] - 25s 16ms/step - loss: 0.2514 - accuracy: 0.9057 - val_loss: 0.3638 - val_accuracy: 0.8802
#
# 테스트 정확도: 0.8726999759674072

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'b-', label='loss')
plt.plot(history.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], 'g-', label='accuracy')
plt.plot(history.history['val_accuracy'], 'k--', label='val_accuracy')
plt.xlabel('Epoch')
plt.ylim(0.7, 1)
plt.legend()

plt.show()

# %%
import matplotlib as mpl
import matplotlib.pylab as plt

'''
plt.rcParams['font.family'] = "Malgun Gothic"
plt.rcParams['font.size'] = 12
plt.rcParams['axes.unicode_minus'] = False
'''

y = [2, 3, 1]
x = np.arange(len(y))
xlabel = ['A', 'B', 'C']
plt.title("Bar Chart")
plt.bar(x, y)
plt.xticks(x, xlabel)
plt.yticks(sorted(y))
plt.xlabel("ABC")
plt.ylabel("Frequency")
plt.show()

# %%
predictions_array = [.1, .15, .2, .05, .5]
predicted_label = np.argmax(predictions_array) # 4
true_label = 2;

thisplot = plt.bar(range(5), predictions_array, color="#999999")
thisplot[0].set_color('yellow')
thisplot[predicted_label].set_color('red')
thisplot[true_label].set_color('blue')

plt.ylim([0, 1])
plt.show()

# %%
def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array[i], true_label[i], img[i]
    plt.xticks([])
    plt.yticks([])
    
    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'
        
    maxprob = np.max(predictions_array)
    plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
               100 * maxprob, class_names[true_label]), color = color)
    
    plt.imshow(img, cmap = plt.cm.binary)

# %%
def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array[i], true_label[i]
    plt.xticks([])
    plt.yticks([])
    plt.ylim([0, 1])
    thisplot = plt.bar(range(10), predictions_array, color="#447777")
    
    predicted_label = np.argmax(predictions_array)
    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')
    x = np.arange(10)
    plt.xticks(x, class_names, rotation='45')

# %%
predictions = model.predict(test_images)

i = 255
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
plot_image(i, predictions, test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions, test_labels)
plt.show()

# %%
def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array[i], true_label[i]
    plt.xticks([])
    plt.yticks([])
    plt.ylim([0, 1])
    thisplot = plt.bar(range(10), predictions_array, color="#447777")
    
    predicted_label = np.argmax(predictions_array)
    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')
    x = np.arange(10)
    xlabel = np.arange(10) 
    plt.xticks(x, xlabel)

# %%
predictions = model.predict(test_images)

i = 255
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
plot_image(i, predictions, test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions, test_labels)
plt.show()

# %%
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))

for i in range(num_images):
    plt.subplot(num_rows, 2*num_cols, 2*i+1)
    plot_image(i, predictions, test_labels, test_images)
    plt.subplot(num_rows, 2*num_cols, 2*i+2)
    plot_value_array(i, predictions, test_labels)

plt.tight_layout()
plt.show()

# %%
pred_result = model.predict(test_images)
pred_labels = tf.argmax(pred_result, axis=1)

mispred = []
for i in range(0, len(test_labels)):
    if pred_labels[i] != test_labels[i]:
        mispred.append(i)
print('정답이 틀린 수', len(mispred))

samples = sorted(sample(mispred, 30))
print(samples)

count = 0
rows, cols = 6, 5
plt.figure(figsize=(12,10))
for i in samples:
    count += 1
    plt.subplot(rows, cols, count)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(test_images[i].reshape(28, 28), cmap='Greys', interpolation='nearest')
    tmp = str(class_names[test_labels[i]]) + ", pred: " + str(class_names[pred_labels[i]])
    plt.title(tmp)

plt.tight_layout()
plt.show()
# Out:
# 정답이 틀린 수 1273
# [163, 250, 630, 966, 1218, 1471, 1501, 1640, 1732, 2399, 2684, 2878, 3084, 3311, 3816, 4040, 4394, 4608, 5082, 5352, 6032, 6934, 6984, 7025, 7177, 7472, 8204, 8949, 9719, 9729]

# %%
count = 0
rows, cols = 10, 6
plt.figure(figsize=(22, 40))

for i in samples:
    count += 1
    plt.subplot(rows, cols, count)
    plot_image(i, pred_result, test_labels, test_images)
    count += 1
    plt.subplot(rows, cols, count)
    plot_value_array(i, pred_result, test_labels)

plt.tight_layout()
plt.show()

# %%
import tensorflow as tf

def get_loss(label, prob):
    cce = tf.keras.losses.SparseCategoricalCrossentropy()
    loss = cce(label, prob)
    return loss 
    
print('CCE: ', get_loss([2], [[0.2, .1, .3, .4]]).numpy())
print('CCE: ', get_loss(2, [0.2, .1, .3, .4]).numpy())
print('CCE: ', get_loss(3, [0.2, .1, .3, .4]).numpy())
print('CCE: ', get_loss(5, [3.5794352e-07, 1.6668336e-09, 1.2257135e-07, 3.7462252e-07, 4.4686758e-06,
 6.8782866e-02, 1.0355227e-06, 5.1593245e-04, 2.1532403e-09, 9.3069482e-01]).numpy())
print('CCE: ', get_loss(9, [3.5794352e-07, 1.6668336e-09, 1.2257135e-07, 3.7462252e-07, 4.4686758e-06,
 6.8782866e-02, 1.0355227e-06, 5.1593245e-04, 2.1532403e-09, 9.3069482e-01]).numpy())
# Out:
# CCE:  1.2039728
# CCE:  1.2039728
# CCE:  0.91629076
# CCE:  2.6768007
# CCE:  0.07182401

# %%
def get_loss(label, prob):
    cce = tf.keras.losses.SparseCategoricalCrossentropy()
    loss = cce(label, prob)
    return loss 

pred_labels = model.predict(test_images)

cces = [] 
for i in range(len(test_images)):
    cces.append(get_loss(test_labels[i], pred_labels[i]).numpy())

print(len(cces))
print(cces[:10])
# Out:
# 10000
# [0.44276744, 0.006855657, 9.5367386e-07, 9.5367386e-07, 0.13901207, 9.5367386e-07, 0.00019774865, 0.0012416281, 9.5367386e-07, 1.5497195e-06]

# %%
import numpy as np
a = np.random.randint(0, 20, 10)
a
# Out:
# array([ 5,  9,  7,  3, 15,  4, 17,  7, 17, 18])

# %%
np.argsort(a)
# Out:
# array([3, 5, 0, 2, 7, 1, 4, 6, 8, 9])

# %%
np.argsort(a)[-1]
# Out:
# 9

# %%
np.argsort(-a)
# Out:
# array([9, 6, 8, 4, 1, 2, 7, 0, 5, 3])

# %%
np.argsort(-a)[0]
# Out:
# 9

# %%
print(a[np.argsort(a)[-1]])
print(a[np.argsort(-a)[0]])
# Out:
# 18
# 18

# %%
print(a[np.argsort(a)[0]])
print(a[np.argsort(-a)[-1]])
# Out:
# 3
# 3

# %%
for _ in range(len(a)):
    print(a[np.argsort(a)[_]], end = ' ')
# Out:
# 3 4 5 7 7 9 15 17 17 18

# %%
for _ in range(len(a)):
    print(a[np.argsort(-a)[_]], end = ' ')
# Out:
# 18 17 17 15 9 7 7 5 4 3

# %%
def plot_value_cce_array(i, predictions_array, true_label):
    plot_value_array(i, predictions_array, true_label)    
    plt.title('CCE: ' + str(get_loss(true_label[i], predictions_array[i]).numpy()))

# %%
arycces = np.array(cces)
lst_arg = np.argsort(-arycces)

for i in range(20):
    print(cces[lst_arg[i]], end = ' ')
print()
# Out:
# 16.118097 16.118095 16.118095 16.118095 13.04327 13.033515 12.665521 11.915296 11.620383 11.357331 11.305943 11.221292 10.954896 10.274035 10.236049 10.2234535 10.149349 10.130464 10.078784 10.037126

# %%
count = 0
rows, cols = 40, 6
plt.figure(figsize=(cols*3, rows*2))

for i in range(rows*3):
    count += 1
    plt.subplot(rows, cols, count)
    plot_image(lst_arg[i], pred_labels, test_labels, test_images)
    count += 1
    plt.subplot(rows, cols, count)
    plot_value_cce_array(lst_arg[i], pred_labels, test_labels)

plt.tight_layout()
plt.show()
